# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
driver = webdriver.Safari()
driver.get('https://www.nike.com/ca/w/sale-3yaep')

# %% [markdown]
# ### scrolling to the end of the webpage

# %%
last_height = driver.execute_script('return document.body.scrollHeight')
while True:
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(3)
    new_height = driver.execute_script('return document.body.scrollHeight')
    if new_height == last_height:
        break
    last_height = new_height

# %% [markdown]
# ### Extracting data from the webpage

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')

# %%
product_card = soup.find_all('div', class_ = 'product-card__body')

# %% [markdown]
# Creating a empty dataframe

# %%
df = pd.DataFrame({'Link':[''], 'Name':[''], 'Subtitle':[''], 'Price':[''], 'Sale Price':['']})

# %%
for product in product_card:
    try:
        link = product.find('a', class_ = 'product-card__link-overlay').get('href')
        name = product.find('div', class_ = 'product-card__title').text
        subtitle = product.find('div', class_ = 'product-card__subtitle').text
        full_price = product.find('div', class_ = 'product-price is--striked-out css-0').text
        sale_price = product.find('div', class_ = 'product-price is--current-price css-1ydfahe').text
        df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
                       ignore_index = True)
    except:
        pass
# Out:
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# ...
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},
# /var/folders/gp/c4myxp8500317j5wjqqwvjr00000gn/T/ipykernel_917/4157906543.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Link':link, 'Name':name, 'Subtitle':subtitle, 'Price':full_price, 'Sale Price':sale_price},

# %%
df
# Out:
#                                                    Link  \
# 0
# 1     https://www.nike.com/ca/t/react-infinity-run-f...
# 2     https://www.nike.com/ca/t/react-ace-tour-golf-...
# 3     https://www.nike.com/ca/t/nikecourt-zoom-pro-h...
# 4     https://www.nike.com/ca/t/blazer-mid-77-shoes-...
# ...                                                 ...
# 1576  https://www.nike.com/ca/t/cortez-basic-txt-vda...
# 1577  https://www.nike.com/ca/t/toronto-raptors-cour...
# 1578  https://www.nike.com/ca/t/ryz-365-shoe-Nn1hTq/...
# 1579  https://www.nike.com/ca/t/yoga-dri-fit-high-ri...
# 1580  https://www.nike.com/ca/t/paris-saint-germain-...
#
#                                    Name  \
# 0
# 1     Nike React Infinity Run Flyknit 3
# 2                   Nike React Ace Tour
# 3                    NikeCourt Zoom Pro
# 4                   Nike Blazer Mid '77
# ...                                 ...
# 1576         Nike Cortez Basic TXT VDAY
# 1577          Toronto Raptors Courtside
# 1578                       Nike Ryz 365
# 1579                  Nike Yoga Dri-FIT
# 1580         Paris Saint-Germain Strike
#
#                                          Subtitle Price Sale Price
# 0
# 1                        Men's Road Running Shoes  $190    $146.99
# 2                               Women's Golf Shoe  $180    $154.99
# 3                 Women's Hard Court Tennis Shoes  $135     $94.99
# 4                                     Men's Shoes  $135    $108.99
# ...                                           ...   ...        ...
# 1576                             Older Kids' Shoe   $95     $75.99
# 1577                     Men's Nike NBA Tracksuit  $170    $139.99
# 1578                                 Women's Shoe  $140    $116.99
# 1579               Women's High-Rise 7/8 Leggings   $74     $65.99
# 1580  Older Kids' Nike Dri-FIT Football Drill Top   $95     $80.99
#
# [1581 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Link        1581 non-null   object
#  1   Name        1581 non-null   object
#  2   Subtitle    1581 non-null   object
#  3   Price       1581 non-null   object
#  4   Sale Price  1581 non-null   object
# dtypes: object(5)
# memory usage: 61.9+ KB
